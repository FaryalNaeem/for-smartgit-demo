# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
mh=pd.read_csv('survey.csv')

# %%
mh
# Out:
#              Timestamp  Age                                          Gender  \
# 0     27/08/2014 11:29   37                                          Female
# 1     27/08/2014 11:29   44                                               M
# 2     27/08/2014 11:29   32                                            Male
# 3     27/08/2014 11:29   31                                            Male
# 4     27/08/2014 11:30   31                                            Male
# 5     27/08/2014 11:31   33                                            Male
# 6     27/08/2014 11:31   35                                          Female
# 7     27/08/2014 11:32   39                                               M
# 8     27/08/2014 11:32   42                                          Female
# 9     27/08/2014 11:32   23                                            Male
# 10    27/08/2014 11:32   31                                            Male
# ...

# %%
mh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
# Timestamp                    1259 non-null object
# Age                          1259 non-null int64
# Gender                       1259 non-null object
# Country                      1259 non-null object
# state                        744 non-null object
# self_employed                1241 non-null object
# family_history               1259 non-null object
# treatment                    1259 non-null object
# work_interfere               995 non-null object
# no_employees                 1259 non-null object
# remote_work                  1259 non-null object
# tech_company                 1259 non-null object
# benefits                     1259 non-null object
# care_options                 1259 non-null object
# wellness_program             1259 non-null object
# seek_help                    1259 non-null object
# anonymity                    1259 non-null object
# ...

# %%
mh.head(10)
# Out:
#           Timestamp  Age  Gender         Country state self_employed  \
# 0  27/08/2014 11:29   37  Female   United States    IL           NaN
# 1  27/08/2014 11:29   44       M   United States    IN           NaN
# 2  27/08/2014 11:29   32    Male          Canada   NaN           NaN
# 3  27/08/2014 11:29   31    Male  United Kingdom   NaN           NaN
# 4  27/08/2014 11:30   31    Male   United States    TX           NaN
# 5  27/08/2014 11:31   33    Male   United States    TN           NaN
# 6  27/08/2014 11:31   35  Female   United States    MI           NaN
# 7  27/08/2014 11:32   39       M          Canada   NaN           NaN
# 8  27/08/2014 11:32   42  Female   United States    IL           NaN
# 9  27/08/2014 11:32   23    Male          Canada   NaN           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often          Jun-25  ...
# 1             No        No         Rarely  More than 1000  ...
# ...

# %% [markdown]
# # Country wise mental health issues

# %%
mh.Country.value_counts().plot.pie()

# %%
US_mh=mh[mh.Country == 'United States']#['state'].value_counts()
US_mh
# Out:
#              Timestamp  Age  Gender        Country state self_employed  \
# 0     27/08/2014 11:29   37  Female  United States    IL           NaN
# 1     27/08/2014 11:29   44       M  United States    IN           NaN
# 4     27/08/2014 11:30   31    Male  United States    TX           NaN
# 5     27/08/2014 11:31   33    Male  United States    TN           NaN
# 6     27/08/2014 11:31   35  Female  United States    MI           NaN
# 8     27/08/2014 11:32   42  Female  United States    IL           NaN
# 10    27/08/2014 11:32   31    Male  United States    OH           NaN
# 12    27/08/2014 11:33   42  female  United States    CA           NaN
# 13    27/08/2014 11:33   36    Male  United States    CT           NaN
# 15    27/08/2014 11:34   29  female  United States    IL           NaN
# 17    27/08/2014 11:34   32    Male  United States    TN           NaN
# 18    27/08/2014 11:34   46    male  United States    MD           Yes
# ...

# %%
import matplotlib.pyplot as plt
US_mh.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Higest ratio statewise

# %%
mh[mh.Country == 'United States']['state'].value_counts()
# Out:
# CA    138
# WA     70
# NY     56
# TN     45
# TX     44
# OH     30
# PA     29
# OR     29
# IL     28
# IN     27
# MI     22
# MN     21
# MA     20
# FL     15
# NC     14
# VA     14
# WI     12
# MO     12
# GA     12
# UT     10
# CO      9
# AL      8
# AZ      7
# MD      7
# NJ      6
# OK      6
# SC      5
# KY      5
# CT      4
# DC      4
# IA      4
# KS      3
# VT      3
# NV      3
# NH      3
# SD      3
# WY      2
# NM      2
# NE      2
# LA      1
# MS      1
# ID      1
# ME      1
# RI      1
# WV      1
# Name: state, dtype: int64

# %%
UK_mh=mh[mh.Country == 'Canada']#['state'].value_counts()
UK_mh
# Out:
#              Timestamp  Age                    Gender Country state  \
# 2     27/08/2014 11:29   32                      Male  Canada   NaN
# 7     27/08/2014 11:32   39                         M  Canada   NaN
# 9     27/08/2014 11:32   23                      Male  Canada   NaN
# 14    27/08/2014 11:33   27                      Male  Canada   NaN
# 36    27/08/2014 11:41   29                      Male  Canada   NaN
# 42    27/08/2014 11:43   27                      Male  Canada   NaN
# 48    27/08/2014 11:43   26                         m  Canada   NaN
# 59    27/08/2014 11:47   33                      male  Canada   NaN
# 64    27/08/2014 11:50   35                      male  Canada   NaN
# 71    27/08/2014 11:53   34                      male  Canada   NaN
# 82    27/08/2014 12:02   30                      male  Canada   NaN
# 94    27/08/2014 12:15   25                         F  Canada   NaN
# 100   27/08/2014 12:18   26                    female  Canada   NaN
# ...

# %%
#mh[(mh['Country'] =='United States') & (mh['Age'] <= 25) & ( mh['family_history']== 'No')]['state'].value_counts()

# %%
#mh[(mh['Country'] =='United States') & (mh['Age'] >= 25) & ( mh['family_history']== 'No')]['state'].value_counts()

# %% [markdown]
# # Awareness

# %%
US_mh[(US_mh.family_history=='Yes') &( US_mh.treatment == 'Yes')]['state'].value_counts()
# Out:
# CA    51
# WA    29
# NY    18
# TN    15
# IL    13
# OR    11
# PA    11
# IN    10
# TX     9
# MI     8
# MN     8
# OH     8
# WI     6
# AL     5
# NC     5
# FL     4
# UT     3
# AZ     3
# VA     3
# GA     3
# MO     3
# MA     3
# CO     2
# MD     2
# NJ     2
# NH     2
# SD     1
# IA     1
# OK     1
# WY     1
# SC     1
# NE     1
# ID     1
# DC     1
# ME     1
# Name: state, dtype: int64

# %%
#US_mh[(US_mh.family_history=='Yes') &( US_mh.treatment == 'No')]['state'].value_counts()

# %% [markdown]
# # US states concerning about their wellness

# %%
US_mh[(US_mh.family_history=='Yes') &( US_mh.treatment == 'Yes')]['state'].value_counts().plot.pie(autopct='%1.1f%%')

# %%
US_mh[(US_mh.family_history=='Yes') &( US_mh.treatment == 'No')]['state'].value_counts().plot.pie(autopct='%1.1f%%')

# %% [markdown]
# # Treatment impacts on Work   >>> result>>> depend on family history

# %%
mh_Awr=US_mh[(US_mh.family_history=='Yes') &( US_mh.treatment == 'Yes')]['work_interfere'].value_counts().plot.pie(autopct='%1.1f%%')

# %%
US_mh[(US_mh.family_history=='Yes') &( US_mh.treatment == 'No')]['work_interfere'].value_counts().plot.pie(autopct='%1.1f%%')

# %%
US_mh[US_mh.treatment == 'Yes']['work_interfere'].value_counts().plot(kind='line')

# %%
US_mh[US_mh.family_history == 'Yes']['work_interfere'].value_counts().plot(kind='line')

# %%
US_mh[US_mh.family_history == 'No']['work_interfere'].value_counts().plot(kind='line')

# %%
US_mh[US_mh.treatment == 'No']['work_interfere'].value_counts().plot(kind='line')

# %% [markdown]
# # trust culture and employee wellness

# %%
US_mh[(US_mh.supervisor == 'Yes') & (US_mh.coworkers == 'Yes')]['state'].value_counts().plot.pie()

# %%
#### Employee wellness program

# %%
US_mh.supervisor.value_counts().plot(kind='line')

# %%
US_mh.coworkers.value_counts().plot(kind='line')

# %%
US_mh.leave.value_counts().plot.pie(autopct='%1.1f%%')

# %%
mh_t=US_mh[(US_mh.supervisor == 'Yes') & (US_mh.coworkers == 'Yes')]['state'].value_counts().plot.pie()
mh_t

# %%
mh_t.unique()
# Out:
# array([16,  8,  7,  6,  5,  3,  2,  1], dtype=int64)
